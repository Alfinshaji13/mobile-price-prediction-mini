# %% [markdown]
# ## Importing essential libraries

# %%
# !pip install -q sklearn
# Out:
# WARNING: You are using pip version 20.2.3; however, version 22.0.2 is available.
# You should consider upgrading via the 'c:\users\shalbin\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\shalbin\appdata\local\programs\python\python38\lib\site-packages (0.11.2)Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 22.0.2 is available.
# You should consider upgrading via the 'C:\Users\SHALBIN\AppData\Local\Programs\Python\Python38\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: scipy>=1.0 in c:\users\shalbin\appdata\local\programs\python\python38\lib\site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\shalbin\appdata\local\programs\python\python38\lib\site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\shalbin\appdata\local\programs\python\python38\lib\site-packages (from seaborn) (1.4.0)
# Requirement already satisfied: numpy>=1.15 in c:\users\shalbin\appdata\local\programs\python\python38\lib\site-packages (from seaborn) (1.22.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shalbin\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shalbin\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (4.29.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\shalbin\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shalbin\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\shalbin\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\shalbin\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\shalbin\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shalbin\appdata\local\programs\python\python38\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\shalbin\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn
from sklearn.feature_selection import SelectKBest,chi2
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn import model_selection
import pickle

# %% [markdown]
# ## Loading train and test datasets

# %%
url_train = "https://raw.githubusercontent.com/Biswa5812/Machine-Learning/master/Mobile%20Price%20Classification/train.csv"
url_test = "https://github.com/Biswa5812/Machine-Learning/blob/master/Mobile%20Price%20Classification/test.csv"

data_train = pd.read_csv(url_train)

# %% [markdown]
# ## Visualizing and Feature Selection

# %%
data_train.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
data_train.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 1995         19        1             1     0            0
# 1996         16        1             1     1            2
# 1997          5        1             1     0            3
# 1998         19        1             1     1            0
# 1999          2        1             1     1            3
#
# [5 rows x 21 columns]

# %%
data_train.isnull().any()
# Out:
# battery_power    False
# blue             False
# clock_speed      False
# dual_sim         False
# fc               False
# four_g           False
# int_memory       False
# m_dep            False
# mobile_wt        False
# n_cores          False
# pc               False
# px_height        False
# px_width         False
# ram              False
# sc_h             False
# sc_w             False
# talk_time        False
# three_g          False
# touch_screen     False
# wifi             False
# price_range      False
# dtype: bool

# %%
data_train['price_range'].value_counts()
# Out:
# 1    500
# 2    500
# 3    500
# 0    500
# Name: price_range, dtype: int64

# %% [markdown]
# ## Univariate Feature Selection

# %%
x = data_train.iloc[:,0:20]
y = data_train.iloc[:,20:]

# %%
print(x.shape)
print(y.shape)
# Out:
# (2000, 20)
# (2000, 1)

# %%
best_feat = SelectKBest(chi2,k=10)
fit = best_feat.fit(x,y)

# %%
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x.columns)

# %%
# concat both dataframes for comparing best scores

score_list = pd.concat([dfcolumns,dfscores],axis=1)
score_list.columns = ["features","scores"]

# %%
score_list
# Out:
#          features         scores
# 0   battery_power   14129.866576
# 1            blue       0.723232
# 2     clock_speed       0.648366
# 3        dual_sim       0.631011
# 4              fc      10.135166
# 5          four_g       1.521572
# 6      int_memory      89.839124
# 7           m_dep       0.745820
# 8       mobile_wt      95.972863
# 9         n_cores       9.097556
# 10             pc       9.186054
# 11      px_height   17363.569536
# 12       px_width    9810.586750
# 13            ram  931267.519053
# 14           sc_h       9.614878
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 17        three_g       0.327643
# 18   touch_screen       1.928429
# 19           wifi       0.422091

# %%
print(score_list.nlargest(10,"scores"))
# Out:
#          features         scores
# 13            ram  931267.519053
# 11      px_height   17363.569536
# 0   battery_power   14129.866576
# 12       px_width    9810.586750
# 8       mobile_wt      95.972863
# 6      int_memory      89.839124
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 4              fc      10.135166
# 14           sc_h       9.614878

# %%
y
# Out:
#       price_range
# 0               1
# 1               2
# 2               2
# 3               2
# 4               1
# ...           ...
# 1995            0
# 1996            2
# 1997            3
# 1998            0
# 1999            3
#
# [2000 rows x 1 columns]

# %% [markdown]
# ## Feature Importance Selection

# %%
feat_imp = ExtraTreesClassifier()
feat_imp.fit(x,y)
# Out:
# C:\Users\SHALBIN\AppData\Local\Temp\ipykernel_6576\2935810956.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   feat_imp.fit(x,y)
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100,
#                      n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)

# %%
print(feat_imp.feature_importances_)
# Out:
# [0.06139661 0.02012893 0.03433535 0.01988856 0.03430182 0.01801694
#  0.03583753 0.03345911 0.03751923 0.0339968  0.03498298 0.04697108
#  0.04836736 0.38017341 0.03467476 0.03508877 0.03614794 0.01487816
#  0.01993008 0.01990461]

# %%
feat_importances = pd.Series(feat_imp.feature_importances_, index=x.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %% [markdown]
# Selecting the top 10 best features and dropping the remaining columns

# %%
data_train.drop(data_train.columns[[1,2,3,5,7,9,10,17,18,19]],axis=1,inplace=True)

# %%
data_train.head()
# Out:
#    battery_power  fc  int_memory  mobile_wt  px_height  px_width   ram  sc_h  \
# 0            842   1           7        188         20       756  2549     9
# 1           1021   0          53        136        905      1988  2631    17
# 2            563   2          41        145       1263      1716  2603    11
# 3            615   0          10        131       1216      1786  2769    16
# 4           1821  13          44        141       1208      1212  1411     8
#
#    sc_w  talk_time  price_range
# 0     7         19            1
# 1     3          7            2
# 2     2          9            2
# 3     8         11            2
# 4     2         15            1

# %% [markdown]
# ## Separating dependent and independent variable

# %%
x = data_train.iloc[:,0:10].values
y = data_train.iloc[:,10:].values

# %%
x
# Out:
# array([[ 842,    1,    7, ...,    9,    7,   19],
#        [1021,    0,   53, ...,   17,    3,    7],
#        [ 563,    2,   41, ...,   11,    2,    9],
#        ...,
#        [1911,    1,   36, ...,    9,    1,    5],
#        [1512,    4,   46, ...,   18,   10,   19],
#        [ 510,    5,   45, ...,   19,    4,    2]], dtype=int64)

# %%
y
# Out:
# array([[1],
#        [2],
#        [2],
#        ...,
#        [3],
#        [0],
#        [3]], dtype=int64)

# %% [markdown]
# ## Applying cross validation technique on various models

# %%
skfold = StratifiedKFold(n_splits=3,random_state=0)
model_c = RandomForestClassifier(criterion='entropy',n_estimators=10,random_state=0,n_jobs=-1)
results_skfold = model_selection.cross_val_score(model_c, x, y.ravel(), cv=skfold)
print("Accuracy: %.2f%%" % (results_skfold.mean()*100.0))

# %%
skfold = StratifiedKFold(n_splits=3,random_state=0)
model_c = KNeighborsClassifier(n_neighbors=10)
results_skfold = model_selection.cross_val_score(model_c, x, y.ravel(), cv=skfold)
print("Accuracy: %.2f%%" % (results_skfold.mean()*100.0))
# Out:
# C:\Users\SHALBIN\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\model_selection\_split.py:292: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# Accuracy: 92.60%

# %%
skfold = StratifiedKFold(n_splits=3,random_state=0)
model_c = DecisionTreeClassifier()
results_skfold = model_selection.cross_val_score(model_c, x, y.ravel(), cv=skfold)
print("Accuracy: %.2f%%" % (results_skfold.mean()*100.0))
# Out:
# Accuracy: 82.05%
# C:\Users\SHALBIN\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\model_selection\_split.py:292: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(

# %% [markdown]
# ##Fitting the Best model on train data

# %%
knn = KNeighborsClassifier(n_neighbors=10)

# %%
knn.fit(x,y)
# Out:
# C:\Users\SHALBIN\AppData\Local\Temp\ipykernel_1736\1361178278.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   knn.fit(x,y)
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %%
pickle.dump(knn,open('model.pkl','wb'))

# %%
test = 'https://github.com/Alfinshaji13/mobile-price-prediction-mini/blob/main/test.csv'
test_data = pd.read_csv(test)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [4], in <module>
#       1 test = 'https://github.com/Alfinshaji13/mobile-price-prediction-mini/blob/main/test.csv'
# ----> 2 test_data = pd.read_csv(test)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\io\parsers\readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\io\parsers\readers.py:1250, in TextFileReader.read(self, nrows)
#    1248 nrows = validate_integer("nrows", nrows)
#    1249 try:
# -> 1250     index, columns, col_dict = self._engine.read(nrows)
#    1251 except Exception:
#    1252     self.close()
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\_libs\parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\_libs\parsers.pyx:861, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\_libs\parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\_libs\parsers.pyx:1960, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 148, saw 2

# %%
test_data.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# 1          7        1             0     0
# 2         10        0             1     1
# 3          7        1             1     0
# 4          7        1             0     1
#
# [5 rows x 21 columns]

# %%
test_data.drop(test_data.columns[[0,2,3,4,6,8,10,11,18,19,20]],axis=1,inplace=True)

# %%
test_data.head()
# Out:
#    battery_power  fc  int_memory  mobile_wt  px_height  px_width   ram  sc_h  \
# 0           1043  14           5        193        226      1412  3476    12
# 1            841   4          61        191        746       857  3895     6
# 2           1807   1          27        186       1270      1366  2396    17
# 3           1546  18          25         96        295      1752  3893    10
# 4           1434  11          49        108        749       810  1773    15
#
#    sc_w  talk_time
# 0     7          2
# 1     0          7
# 2    10         10
# 3     0          7
# 4     8          7

# %%
x_test = test_data.iloc[:,0:20].values

# %%
x_test
# Out:
# array([[1043,   14,    5, ...,   12,    7,    2],
#        [ 841,    4,   61, ...,    6,    0,    7],
#        [1807,    1,   27, ...,   17,   10,   10],
#        ...,
#        [1185,    1,    8, ...,    5,    0,   14],
#        [1533,    0,   50, ...,   15,   11,    6],
#        [1270,    4,   35, ...,    9,    2,    3]], dtype=int64)

# %%
x.shape
# Out:
# (2000, 10)

# %%
x_test.shape
# Out:
# (1000, 10)

# %%
knn.predict(x_test)
# Out:
# array([3, 3, 3, 3, 1, 3, 3, 1, 3, 0, 3, 3, 0, 0, 2, 0, 2, 1, 3, 2, 1, 3,
#        1, 1, 3, 0, 2, 0, 3, 0, 2, 0, 3, 0, 0, 1, 3, 1, 2, 1, 1, 2, 0, 0,
#        0, 1, 0, 3, 1, 2, 1, 0, 3, 0, 3, 0, 3, 1, 1, 3, 3, 2, 0, 1, 1, 1,
#        1, 3, 1, 2, 1, 2, 2, 3, 3, 0, 2, 0, 2, 3, 0, 3, 3, 0, 3, 0, 3, 1,
#        3, 0, 1, 2, 2, 1, 2, 2, 0, 2, 1, 2, 1, 0, 0, 3, 0, 2, 0, 1, 2, 3,
#        3, 3, 1, 3, 3, 3, 3, 1, 3, 0, 0, 3, 2, 1, 2, 0, 3, 2, 3, 1, 0, 2,
#        1, 1, 3, 1, 1, 0, 3, 2, 1, 2, 1, 2, 2, 3, 3, 2, 2, 3, 2, 3, 1, 0,
#        3, 2, 3, 3, 3, 3, 2, 2, 3, 3, 3, 3, 1, 0, 3, 0, 0, 0, 1, 1, 0, 1,
#        0, 0, 1, 2, 1, 0, 0, 1, 1, 2, 2, 1, 0, 0, 0, 1, 0, 3, 1, 0, 2, 2,
#        3, 3, 1, 2, 2, 2, 3, 2, 2, 1, 0, 0, 1, 2, 0, 2, 3, 3, 0, 2, 0, 3,
#        2, 2, 3, 1, 0, 1, 0, 3, 0, 1, 0, 2, 2, 1, 2, 0, 3, 0, 3, 1, 2, 0,
#        0, 2, 1, 3, 3, 3, 1, 1, 3, 0, 0, 2, 3, 3, 1, 3, 1, 1, 3, 2, 1, 2,
#        3, 3, 3, 1, 0, 0, 2, 3, 1, 1, 3, 2, 0, 3, 0, 0, 3, 0, 0, 3, 2, 3,
#        3, 2, 1, 3, 3, 2, 3, 1, 2, 1, 2, 0, 2, 3, 1, 0, 0, 3, 0, 3, 0, 1,
#        2, 0, 2, 3, 1, 3, 2, 2, 1, 2, 0, 0, 0, 1, 3, 2, 0, 0, 0, 3, 2, 0,
#        2, 3, 1, 2, 2, 2, 3, 1, 3, 3, 2, 2, 2, 3, 3, 0, 3, 1, 3, 1, 3, 1,
#        3, 3, 0, 1, 0, 3, 1, 3, 2, 3, 0, 0, 0, 0, 2, 0, 0, 2, 2, 1, 2, 2,
#        2, 0, 1, 0, 0, 3, 2, 0, 3, 1, 2, 2, 1, 2, 3, 1, 1, 2, 2, 1, 2, 0,
#        1, 1, 0, 3, 2, 1, 0, 1, 0, 0, 1, 1, 0, 0, 0, 2, 2, 3, 2, 3, 0, 3,
#        0, 3, 0, 1, 1, 1, 1, 0, 3, 2, 3, 3, 1, 3, 1, 3, 1, 3, 2, 0, 1, 2,
#        1, 2, 0, 0, 0, 1, 2, 1, 0, 3, 2, 0, 2, 2, 0, 0, 3, 1, 1, 0, 3, 2,
#        3, 0, 3, 0, 2, 3, 3, 3, 0, 2, 0, 2, 3, 0, 1, 1, 0, 0, 1, 1, 1, 3,
#        3, 3, 2, 3, 1, 2, 2, 2, 3, 3, 2, 0, 2, 1, 2, 2, 1, 0, 2, 2, 0, 0,
#        0, 3, 1, 0, 2, 2, 2, 0, 3, 0, 2, 2, 0, 3, 0, 2, 3, 0, 1, 1, 3, 3,
#        1, 1, 2, 3, 2, 0, 2, 1, 2, 0, 3, 3, 1, 2, 2, 2, 3, 0, 1, 2, 3, 1,
#        3, 2, 3, 1, 1, 0, 0, 3, 1, 0, 3, 2, 3, 2, 0, 3, 3, 3, 2, 3, 3, 1,
#        2, 0, 2, 2, 3, 1, 0, 1, 1, 2, 2, 1, 0, 0, 2, 2, 3, 2, 0, 2, 1, 3,
#        3, 0, 1, 3, 0, 2, 1, 1, 0, 0, 2, 1, 0, 1, 1, 2, 2, 0, 2, 2, 1, 0,
#        3, 0, 0, 3, 2, 0, 0, 0, 0, 0, 3, 0, 3, 1, 3, 2, 1, 3, 3, 0, 1, 0,
#        3, 2, 2, 2, 0, 3, 0, 2, 0, 2, 0, 0, 1, 1, 1, 2, 1, 3, 1, 3, 2, 2,
#        1, 3, 2, 0, 1, 2, 0, 3, 3, 0, 2, 1, 1, 2, 0, 3, 2, 0, 3, 2, 3, 0,
#        0, 3, 0, 2, 2, 3, 2, 2, 2, 2, 1, 2, 3, 0, 1, 1, 1, 2, 1, 0, 0, 1,
#        0, 0, 3, 0, 1, 2, 0, 0, 1, 1, 3, 0, 3, 2, 3, 0, 0, 1, 2, 1, 1, 0,
#        1, 1, 0, 1, 1, 0, 0, 3, 3, 0, 2, 1, 2, 3, 0, 1, 0, 2, 2, 0, 3, 1,
#        0, 3, 1, 1, 0, 3, 3, 3, 2, 3, 0, 3, 2, 0, 0, 0, 3, 3, 2, 0, 1, 1,
#        2, 0, 0, 3, 2, 0, 3, 1, 2, 1, 1, 1, 3, 1, 1, 1, 2, 0, 0, 2, 2, 0,
#        2, 0, 0, 0, 0, 2, 3, 3, 3, 0, 1, 2, 2, 1, 0, 0, 2, 1, 0, 2, 0, 2,
#        2, 2, 1, 2, 0, 2, 1, 3, 0, 0, 3, 2, 3, 0, 0, 2, 3, 3, 1, 2, 2, 1,
#        0, 0, 2, 3, 0, 3, 0, 0, 0, 2, 2, 1, 2, 0, 3, 2, 1, 2, 3, 3, 0, 1,
#        1, 2, 1, 2, 2, 0, 1, 3, 1, 1, 3, 0, 2, 3, 2, 1, 1, 1, 3, 2, 0, 2,
#        3, 0, 2, 3, 2, 2, 2, 3, 2, 0, 1, 2, 0, 2, 1, 1, 2, 2, 2, 1, 2, 1,
#        1, 1, 3, 1, 0, 1, 2, 3, 1, 0, 0, 2, 2, 2, 3, 0, 3, 3, 2, 1, 3, 0,
#        1, 3, 1, 2, 1, 1, 3, 2, 0, 3, 0, 2, 3, 0, 3, 1, 2, 3, 1, 0, 2, 3,
#        1, 0, 2, 1, 2, 1, 2, 0, 2, 2, 0, 2, 3, 2, 3, 0, 2, 1, 1, 2, 2, 3,
#        3, 0, 2, 1, 2, 1, 3, 0, 0, 3, 0, 1, 0, 0, 3, 3, 2, 0, 0, 0, 0, 3,
#        2, 3, 3, 0, 0, 2, 1, 0, 2, 2], dtype=int64)
